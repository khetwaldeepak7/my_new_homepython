# %%
import requests
import bs
re=requests.get("https://www.yankeecandle.co.uk/")
# <li class="dropdown subMenu">

# %%
re.text   # in the re all the text had stored
# Out:
# '<!DOCTYPE html><html lang="en"><head><title class="next-head">Yankee Candle - Candles, Candle Accessories &amp; Home Fragrance</title><meta charSet="utf-8" class="next-head"/><meta name="description" property="description" content="Shop our collection of candles, home fragrance, accessories, gifts and special offers online. Free Standard UK Delivery available." class="next-head"/><meta name="keywords" property="keywords" content="" class="next-head"/><meta name="robots" content="index, follow" class="next-head"/><meta name="og:title" content="Yankee Candle - Candles, Candle Accessories &amp; Home Fragrance" class="next-head"/><meta name="og:site_name" content="Yankee Candle" class="next-head"/><meta name="og:image" content="https://www.yankeecandle.com/statics/images/icons/ycc_header_logo.png" class="next-head"/><meta name="og:description" content="Shop our collection of candles, home fragrance, accessories, gifts and special offers online. Free Standard UK Delivery available." clas
# ...

# %%
soup=bs4.BeautifulSoup(re.text,'lxml')
#soup = BeautifulSoup(html_doc, 'html.parser')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
soup.title
# Out:
# <title class="next-head">Yankee Candle - Candles, Candle Accessories &amp; Home Fragrance</title>

# %%
# this is way we can create a directory for program,suppose the file is already created than it will not create a new one

# %%
import os  # imported the os
def create_directory(directory):
    if not os.path.exists(directory):  # it chcek where the file we are creating is present or no,if not
        print("created new directory:",directory)  # it will create new directory
        os.makedirs(directory)  # humne uper file ka naam dia hai but how computer will know ki directory nana hai,bby using this method n make a new directory with the help of this method
create_directory("deepak web crawling project")  # to create the directory

# %%
def create_data(projectname,baseurl):
#--->>by this format we will create a file inside the existing folder,as we know the projrctname is passed while calling the function
    queue=projectname+'/queue.txt'   # it will for to save the name of file as we passed in the string isside theprojectname
    crawled=projectname+'/crawled.txt'   
    if not os.path.isfile(queue):  # if queue mai koe file nhi hai toh queue mai file bna,jismai baseurl daleyyga
        write_file(queue,baseurl)  # .here made a write_file function call    dont keep ot empty;jismai do chix define kia hai,queue,path ,and baseurl
    if not os.path.isfile(crawled):
        write_file(crawled,'')  # while creating a crawl file make it alway empty

# %%
#-->jabh eskoa call kia (projectname,url pas kia)
#-->when it got first time call

def write_file(path,data):  #here the write _path function define.it take 2 argument,name of file n utl
    f=open(path,'w')  # file handling,open a file of name what everi the path in a write mode
    #--->path name is queue inthe first time
    f.write(data)  # data mai first time  queue file mai data mai url daleyg
    f.close()

# %%
create_data('deepak web crawling project','https://www.yankeecandle.co.uk/')

# %%
def append_to_file(path,baseurl):
    file=open(path,'a')
    file.write(data+'\n')  # url will comes in new line

# %%
#to delete the contents of file

# %%
def delete_file(path):
    with open(path,'w'):
        pass

# %%
#read the file and convert it into the set
def sets(filename):
    results=set()
   # with open(filename,'rt') as f: #another way to open a file
    f=open(filename,'rt')  # rt mean read in a text formatr
    # read one oneline n convert 
    for line in f:   # f sey read kareyga and line mai ayega,ek ek karke
        result.add(line,replace('\n'),'')   # as we know when we will take a new line so to avoid that we will use the concept of replace 
    return result

# %%
def set_to_file(links,file):
    delete_file_contents(file)
    for links  in sorted(links):
           append_to_file(file,link)
